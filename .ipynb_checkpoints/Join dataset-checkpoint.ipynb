# %%
import pandas as pd
import numpy as np
import re

from math import sin, cos, sqrt, atan2, radians
import matplotlib.pyplot as plt

import googlemaps

# %%
def distance_between_points(lat1,lon1,lat2,lon2):
    
# approximate radius of earth in km
    R = 6378.0

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %%
# Read Dataset
poi1_df = pd.read_csv("Dataset/Landmarks_and_places_of_interest__including_schools__theatres__health_services__sports_facilities__places_of_worship__galleries_and_museums. (1).csv")
poi2_df = pd.read_csv("Dataset/EventVenuePointsExternal.csv")
bbq_df = pd.read_csv("Dataset/Public_barbecues.csv")

# Toilet Dataset
toilet_df = pd.read_csv("Dataset/Public_toilets.csv")
toilet_df1 = toilet_df

# Water Fountain Dataset
water_df = pd.read_csv('Dataset/Drinking_fountains.csv')

# %% [markdown]
# ### Clean up POI1 dataset
#
# Section Information :
# <table style="margin-left:0">
#     <tr>
#         <td>Date</td>
#         <td>: </td>
#         <td> 9 April 2020 </td>
#     </tr>
#      <tr>
#         <td>Time Start</td>
#         <td>: </td>
#         <td> 10.50 PM </td>
#     </tr>
#     </table>

# %%
poi1_df.head()
# Out:
#                 Theme                                        Sub Theme  \
# 0           Transport                                  Railway Station
# 1           Mixed Use                            Retail/Office/Carpark
# 2   Place Of Assembly                                          Library
# 3  Leisure/Recreation  Informal Outdoor Facility (Park/Garden/Reserve)
# 4    Place of Worship                                           Church
#
#                         Feature Name                           Co-ordinates
# 0  Flemington Bridge Railway Station  (-37.7881645889621, 144.939277838304)
# 1              Council House 2 (CH2)  (-37.8142591432011, 144.966638432727)
# 2    The Melbourne Athenaeum Library  (-37.8148855756416, 144.967291289941)
# 3              Carlton Gardens South  (-37.8060684577258, 144.971266479841)
# 4                  St Francis Church  (-37.8118847831837, 144.962422614541)

# %%
# Separate Co-ordinates
poi1_df['lat']  = [coord.split('(')[1].split(', ')[0] for coord in poi1_df['Co-ordinates']]
poi1_df['lon'] = [coord.split(')')[0].split(', ')[1] for coord in poi1_df['Co-ordinates']]
poi1_df.head()
# Out:
#                 Theme                                        Sub Theme  \
# 0           Transport                                  Railway Station
# 1           Mixed Use                            Retail/Office/Carpark
# 2   Place Of Assembly                                          Library
# 3  Leisure/Recreation  Informal Outdoor Facility (Park/Garden/Reserve)
# 4    Place of Worship                                           Church
#
#                         Feature Name                           Co-ordinates  \
# 0  Flemington Bridge Railway Station  (-37.7881645889621, 144.939277838304)
# 1              Council House 2 (CH2)  (-37.8142591432011, 144.966638432727)
# 2    The Melbourne Athenaeum Library  (-37.8148855756416, 144.967291289941)
# 3              Carlton Gardens South  (-37.8060684577258, 144.971266479841)
# 4                  St Francis Church  (-37.8118847831837, 144.962422614541)
#
#                  lat               lon
# 0  -37.7881645889621  144.939277838304
# 1  -37.8142591432011  144.966638432727
# 2  -37.8148855756416  144.967291289941
# 3  -37.8060684577258  144.971266479841
# 4  -37.8118847831837  144.962422614541

# %%
set(poi1_df['Sub Theme'])
# Out:
# {'Aquarium',
#  'Art Gallery/Museum',
#  'Bridge',
#  'Casino',
#  'Cemetery',
#  'Church',
#  'Cinema',
#  'Current Construction Site',
#  'Current Construction Site - Commercial',
#  'Department Store',
#  'Dwelling (House)',
#  'Film & RV Studio',
#  'Fire Station',
#  'Function/Conference/Exhibition Centre',
#  'Further Education',
#  'Government Building',
#  'Gymnasium/Health Club',
#  'Hostel',
#  'Indoor Recreation Facility',
#  'Industrial (Manufacturing)',
#  'Informal Outdoor Facility (Park/Garden/Reserve)',
#  'Library',
#  'Major Sports & Recreation Facility',
#  'Marina',
#  'Medical Services',
#  'Observation Tower/Wheel',
#  'Office',
#  'Outdoor Recreation Facility (Zoo, Golf Course)',
#  'Police Station',
#  'Primary Schools',
#  'Private Hospital',
#  'Private Sports Club/Facility',
#  'Public Buildings',
#  'Public Hospital',
#  'Railway Station',
#  'Retail',
#  'Retail/Office',
#  'Retail/Office/Carpark',
#  'Retail/Office/Residential/Carpark',
#  'Retail/Residential',
#  'School - Primary and Secondary Education',
#  'Secondary Schools',
#  'Store Yard',
#  'Synagogue',
#  'Tertiary (University)',
#  'Theatre Live',
#  'Transport Terminal',
#  'Vacant Land - Undeveloped Site',
#  'Visitor Centre'}

# %%
# Set USE = nan
poi1_df['Use'] = 'nan'

# From Community Use, we will only take the public buildings, exclude courts
## 1. Use = 0 for non Community Use
poi1_df.loc[(poi1_df['Theme'] == 'Community Use') & (poi1_df['Sub Theme']!= 'Public Buildings') , 'Use'] = 0

## 2. Use = 1 for other community use  excluding courts
for idx in poi1_df.loc[(poi1_df['Theme'] == 'Community Use') & (poi1_df['Use']!= 0) ].index:
    # Find court in the Feature name
    if(re.search('court', poi1_df.loc[idx]['Feature Name'].lower()) != None ):
        poi1_df.loc[idx,'Use'] = 0
    else :
        poi1_df.loc[idx,'Use'] = 1
        
# Can use POI: 
poi1_df.loc[poi1_df['Theme'].isin(["Mixed Use",
                                    "Place Of Assembly",
                                    "Place of Worship",
                                    "Purpose Built",
                                    "Retail",
                                    "Transport",
                                    "Leisure/Recreation"]),'Use'] = 1

# Cannot Use POI:
poi1_df.loc[poi1_df['Theme'].isin(["Education Centre",
                                    "Office",
                                    "Health Services",
                                    "Industrial", 
                                    "Office", 
                                    "Residential Accommodation", 
                                    "Specialist Residential Accommodation", 
                                    "Vacant Land", 
                                    "Warehouse/Store"]),'Use'] = 0

# Adding some of the useless Sub Theme POI
poi1_df.loc[poi1_df['Sub Theme'].isin(["Bridge",
                                    "Film & RV Studio",
                                    "Transport Terminal",
                                    "Retail/Residential", 
                                    "Railway Station",
                                    "Retail/Office/Residential/Carpark"]),'Use'] = 0

# %%
poi1_final = poi1_df[poi1_df['Use']==1][['Theme','Sub Theme','Feature Name','lat','lon']]
poi1_final['lon'] = pd.to_numeric(poi1_final['lon'])
poi1_final['lat'] = pd.to_numeric(poi1_final['lat'])
# Set poi_id 
poi1_final = poi1_final.reset_index()
poi1_final['poi_id'] = [i+1 for i in poi1_final.index]
print("Number of POI from poi1:" , len(poi1_final))
poi1_final_csv = poi1_final[['poi_id','Feature Name','Theme', 'Sub Theme', 'lat','lon']]
poi1_final_csv.columns= ['poi_id','Name','Theme', 'Sub Theme', 'lat','lon']

poi1_final_csv.to_csv('Dataset/Final/POI_FINAL.csv',index=False)
# Out:
# Number of POI from poi1: 157

# %% [markdown]
# ### Clean up and Join Public Toilet Dataset
#
# Section Information :
# <table style="margin-left:0">
#     <tr>
#         <td>Date</td>
#         <td>: </td>
#         <td> 10 April 2020 </td>
#     </tr>
#      <tr>
#         <td>Time Start</td>
#         <td>: </td>
#         <td> 8.40 PM </td>
#     </tr>
#      <tr>
#         <td>End Start</td>
#         <td>: </td>
#         <td> 8.40 PM </td>
#     </tr>
#     </table>

# %%
toilet_df1['lon'] = pd.to_numeric(toilet_df1['lon'])
toilet_df1['lat'] = pd.to_numeric(toilet_df1['lat'])
print(toilet_df1.head())
print(toilet_df1.describe())
# Out:
#                                                 name female male wheelchair  \
# 0  Public Toilet - Toilet 140 - Queensberry Stree...     no  yes         no
# 1  Public Toilet - Toilet 106 - Kings Domain Gove...    yes  yes         no
# 2  Public Toilet - Queen Victoria Market (153 Vic...    yes  yes         no
# 3  Public Toilet - Victoria Harbour, Shed 3 (Nort...     no  yes         no
# 4  Public Toilet - Toilet 6 - Elizabeth Street (T...    yes   no         no
#
#             operator baby_facil        lat         lon
# 0  City of Melbourne         no -37.803995  144.959091
# 1  City of Melbourne         no -37.826916  144.974648
# 2  City of Melbourne         no -37.806121  144.956538
# 3  City of Melbourne         no -37.819796  144.937665
# 4  City of Melbourne         no -37.813838  144.963097
#              lat         lon
# count  74.000000   74.000000
# mean  -37.810676  144.961615
# std     0.014212    0.014872
# min   -37.845207  144.921106
# 25%   -37.819286  144.955233
# 50%   -37.812138  144.962886
# 75%   -37.802803  144.972442
# max   -37.778950  144.986859

# %%
poi1_final
# Out:
#      index               Theme  \
# 0        1           Mixed Use
# 1        2   Place Of Assembly
# 2        3  Leisure/Recreation
# 3        4    Place of Worship
# 4        5    Place of Worship
# ..     ...                 ...
# 152    234              Retail
# 153    235              Retail
# 154    236  Leisure/Recreation
# 155    240   Place Of Assembly
# 156    241           Mixed Use
#
#                                            Sub Theme  \
# 0                              Retail/Office/Carpark
# 1                                            Library
# 2    Informal Outdoor Facility (Park/Garden/Reserve)
# 3                                             Church
# 4                                             Church
# ..                                               ...
# 152                                 Department Store
# 153                                 Department Store
# 154  Informal Outdoor Facility (Park/Garden/Reserve)
# 155                               Art Gallery/Museum
# 156                            Retail/Office/Carpark
#
#                                  Feature Name        lat         lon  poi_id
# 0                       Council House 2 (CH2) -37.814259  144.966638       1
# 1             The Melbourne Athenaeum Library -37.814886  144.967291       2
# 2                       Carlton Gardens South -37.806068  144.971266       3
# 3                           St Francis Church -37.811885  144.962423       4
# 4                               Wesley Church -37.810158  144.968168       5
# ..                                        ...        ...         ...     ...
# 152                                      Myer -37.813591  144.963855     153
# 153                               David Jones -37.813313  144.964373     154
# 154                            Lincoln Square -37.802792  144.962761     155
# 155  The Museum Of Australian Chinese History -37.810769  144.969234     156
# 156                         ANZ 'Gothic' Bank -37.816158  144.961674     157
#
# [157 rows x 7 columns]

# %%
def get_nearest_items(lat,lon,poi_id, df, restriction=1):
    '''
    Given the latitude, longitude, and the respective poi_id
    output : dataframe of the nearest public toilet
    '''
    place_df = df
    # Get the differences between points
    place_df['distance'] =np.vectorize(distance_between_points)(lat,lon,place_df['lat'], place_df['lon'])
    
    place_sort_df = place_df.sort_values(by='distance').reset_index()
    # Make sure atleast there is 1 female, male, and wheelchair accessible toilet
    show = 3 
    if restriction == 1 :
        while ((len(place_sort_df.head(show).loc[place_sort_df['female'] == 'yes']) < 1) &
              (len(place_sort_df.head(show).loc[place_sort_df['male'] == 'yes']) < 1) &
              (len(place_sort_df.head(show).loc[place_sort_df['wheelchair'] == 'yes']) <1)):
            show = show+1
            if show > 6:
                break
    place_sort_df['poi_id'] = poi_id
    
    return place_sort_df.head(show)

# %%
for i in poi1_final.index:
    res_df = get_nearest_items(poi1_final.loc[i]['lat'],
                         poi1_final.loc[i]['lon'],
                         poi1_final.loc[i]['poi_id'],
                        toilet_df)

    if i==0:
        toilet_final_df = res_df
    else:
        toilet_final_df = toilet_final_df.append(res_df)
            
# np.vectorize(get_toilets)(poi1_final['lat'],poi1_final['lat'],poi1_final['Feature Name'])
# get_toilets(-37.8069431,144.9588825, 'Queen Victoria Market')

# %%
toilet_final_df.head()
# Out:
#    index                                               name female male  \
# 0     30  Public Toilet - Town Hall Melbourne (200 Colli...    yes  yes
# 1     61  Public Toilet - Toilet 46 - Bourke Street (opp...    yes  yes
# 2      4  Public Toilet - Toilet 6 - Elizabeth Street (T...    yes   no
# 0     30  Public Toilet - Town Hall Melbourne (200 Colli...    yes  yes
# 1     61  Public Toilet - Toilet 46 - Bourke Street (opp...    yes  yes
#
#   wheelchair           operator baby_facil        lat         lon   distance  \
# 0        yes  City of Melbourne        yes -37.815216  144.966943   6.399730
# 1        yes  City of Melbourne         no -37.813245  144.966897   6.669144
# 2         no  City of Melbourne         no -37.813838  144.963097  22.597263
# 0        yes  City of Melbourne        yes -37.815216  144.966943   3.048874
# 1        yes  City of Melbourne         no -37.813245  144.966897  10.755594
#
#    poi_id
# 0       1
# 1       1
# 2       1
# 0       2
# 1       2

# %%
# Save the dataset
# toilet_final_df = toilet_final_df.reset_index()
toilet_final_df['toilet_id'] = [i+1 for i in toilet_final_df.index]
toilet_final_df = toilet_final_df[['toilet_id','poi_id','name','female','male','wheelchair','lat','lon','distance']]
toilet_final_df.to_csv('Dataset/Final/Nearest_public_toilet.csv', index=False)

# %% [markdown]
# ## DONE HERE for ITERATION 1

# %% [markdown]
# ### Fixing Double Entry

# %%
# Find double entry
for i in poi1_final.index:
    near_poi = [poi1_final.loc[j,'Feature Name']  for j in poi1_final.index if (distance_between_points(poi1_final.loc[i,'lat'],
                                                            poi1_final.loc[j,'lon'],
                                                            poi1_final.loc[j,'lat'],
                                                            poi1_final.loc[i,'lon']) < 6) & (i!= j )]
    
    poi_idx = [j for j in poi1_final.index if (distance_between_points(poi1_final.loc[i,'lat'],
                                                            poi1_final.loc[j,'lon'],
                                                            poi1_final.loc[j,'lat'],
                                                            poi1_final.loc[i,'lon']) < 6) & (i!= j )]
    
    
    poi1_final.loc[i,'Near'] = str(near_poi)
    poi1_final.loc[i,'poi_idx'] = str(poi_idx)
    poi1_final.loc[i,'Count'] = len(near_poi)

# %%
poi1_final.loc[100]
# Out:
# index                                                       138
# Theme                                        Leisure/Recreation
# Sub Theme       Informal Outdoor Facility (Park/Garden/Reserve)
# Feature Name                 North Melbourne Recreation Reserve
# lat                                                    -37.7988
# lon                                                     144.941
# poi_id                                                      101
# Near                                                         []
# poi_idx                                                      []
# Count                                                         0
# Name: 100, dtype: object

# %% [markdown]
# ### GOOGLE MAPS

# %%
# gmaps = googlemaps.Client(key='AIzaSyAJA2i0GRCZV3EweKSBfMggeLuP9iZ3zhA')
# res = gmaps.reverse_geocode((-37.810769,144.969234))
# res[0]['formatted_address']

# %% [markdown]
# ### Adding Address to Dataset
# https://data.melbourne.vic.gov.au/Property/Street-addresses/a7rp-xtya

# %%
add_df = pd.read_csv('Dataset/Address_Points.csv')

# %%
add_df2 = add_df[['LATITUDE','LONGITUDE','AddressPnt']]
add_df2.columns = ['lat','lon','Address']
# add_df2['lon'] = pd.to_numeric(add_df2['lon']).round(4)
# add_df2['lat'] = pd.to_numeric(add_df2['lat']).round(4)

# %%
def get_address(lat,lon):
    '''
    Given the latitude and longitude
    output : Address - string
    '''
    address_df = add_df2
    # Get the differences between points
    address_df['distance'] =np.vectorize(distance_between_points)(lat,lon,address_df['lat'], address_df['lon'])
    address_sort_df = address_df.sort_values(by='distance').reset_index()
    
    # Uncomment to debug, the distance between point and address
    # print(address_sort_df.loc[0]['distance'], address_sort_df.loc[0]['Address'])
    return address_sort_df.loc[0]['Address']

# %%
# Get the address
poi1_final['Address'] = np.vectorize(get_address)(poi1_final['lat'],poi1_final['lon'])
# Out:
# /Users/lilianaester/anaconda3/envs/newwnv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
poi1_final
# Out:
#      index               Theme  \
# 0        1           Mixed Use
# 1        2   Place Of Assembly
# 2        3  Leisure/Recreation
# 3        4    Place of Worship
# 4        5    Place of Worship
# ..     ...                 ...
# 152    234              Retail
# 153    235              Retail
# 154    236  Leisure/Recreation
# 155    240   Place Of Assembly
# 156    241           Mixed Use
#
#                                            Sub Theme  \
# 0                              Retail/Office/Carpark
# 1                                            Library
# 2    Informal Outdoor Facility (Park/Garden/Reserve)
# 3                                             Church
# 4                                             Church
# ..                                               ...
# 152                                 Department Store
# 153                                 Department Store
# 154  Informal Outdoor Facility (Park/Garden/Reserve)
# 155                               Art Gallery/Museum
# 156                            Retail/Office/Carpark
#
#                                  Feature Name        lat         lon  poi_id  \
# 0                       Council House 2 (CH2) -37.814259  144.966638       1
# 1             The Melbourne Athenaeum Library -37.814886  144.967291       2
# 2                       Carlton Gardens South -37.806068  144.971266       3
# 3                           St Francis Church -37.811885  144.962423       4
# 4                               Wesley Church -37.810158  144.968168       5
# ..                                        ...        ...         ...     ...
# 152                                      Myer -37.813591  144.963855     153
# 153                               David Jones -37.813313  144.964373     154
# 154                            Lincoln Square -37.802792  144.962761     155
# 155  The Museum Of Australian Chinese History -37.810769  144.969234     156
# 156                         ANZ 'Gothic' Bank -37.816158  144.961674     157
#
#                                                   Near           poi_idx  \
# 0    ['The Melbourne Athenaeum Library', 'Melbourne...           [1, 65]
# 1    ['Council House 2 (CH2)', 'Collins Street Bapt...  [0, 27, 65, 110]
# 2                                                   []                []
# 3                                                   []                []
# 4                                                   []                []
# ..                                                 ...               ...
# 152                                    ['David Jones']             [153]
# 153                                           ['Myer']             [152]
# 154                                                 []                []
# 155                          ["Her Majesty's Theatre"]             [116]
# 156                                                 []                []
#
#      Count                                         Address
# 0      2.0            236 Little Collins Street  Melbourne
# 1      4.0                   190 Collins Street  Melbourne
# 2      0.0  Carlton Gardens South Victoria Street  Carlton
# 3      0.0                 274 Elizabeth Street  Melbourne
# 4      0.0                  138 Lonsdale Street  Melbourne
# ..     ...                                             ...
# 152    1.0                    328 Bourke Street  Melbourne
# 153    1.0                    308 Bourke Street  Melbourne
# 154    0.0                24 Lincoln Square South  Carlton
# 155    1.0                       20 Cohen Place  Melbourne
# 156    0.0                      96 Queen Street  Melbourne
#
# [157 rows x 11 columns]

# %%
poi1_final[['poi_id','Feature Name','Theme','Sub Theme','Address','lat','lon']].to_csv('Dataset/Final/POI_FINAL.csv',index=False)

# %%
pd.DataFrame(set(poi1_final['Sub Theme'])).to_csv('subtheme.csv')
# set(poi1_final[['Sub Theme','Theme']])

# %%
set(poi1_final['Theme'])
# Out:
# {'Community Use',
#  'Leisure/Recreation',
#  'Mixed Use',
#  'Place Of Assembly',
#  'Place of Worship',
#  'Purpose Built',
#  'Retail',
#  'Transport'}

# %%
set(poi1_final[poi1_final['Theme'] == 'Leisure/Recreation']['Sub Theme'])
# Out:
# {'Gymnasium/Health Club',
#  'Indoor Recreation Facility',
#  'Informal Outdoor Facility (Park/Garden/Reserve)',
#  'Major Sports & Recreation Facility',
#  'Observation Tower/Wheel',
#  'Outdoor Recreation Facility (Zoo, Golf Course)',
#  'Private Sports Club/Facility'}

# %%
poi1_final[poi1_final['Sub Theme']=='Gymnasium/Health Club']
# Out:
#      index               Theme              Sub Theme  \
# 138    210  Leisure/Recreation  Gymnasium/Health Club
#
#                                       Feature Name        lat         lon  \
# 138  North Melbourne Recreation Centre (Gymnasium) -37.799705  144.940368
#
#      poi_id Near poi_idx  Count                            Address
# 138     139   []      []    0.0  206 Arden Street  North Melbourne

# %%
len(poi1_final)
# Out:
# 157

# %% [markdown]
# ### Adding The Group Activity
#
# Created : 22 April 2020

# %%
list_interest = ['library',
                 'cinema',
                 'sport',
                 'hangout',
                 'religious',
                 'spectator of sport',
                 'museum',
                 'park',
                 'shopping']

# %%
# Create a zip object from two lists
zipbObj = zip(list_interest, [x+1 for x in range(len(list_interest))])
 
# Create a dictionary from zip object
interest_dict = dict(zipbObj)

# %%
interest_dict
# Out:
# {'library': 1,
#  'cinema': 2,
#  'sport': 3,
#  'hangout': 4,
#  'religious': 5,
#  'spectator of sport': 6,
#  'museum': 7,
#  'park': 8,
#  'shopping': 9}

# %%
poi_sub_theme_activity_dict = dictionary = {
    "Function/Conference/Exhibition Centre":["hangout"],
    "Retail/Office":["shopping"],
    "Synagogue":["religious"],
    "Department Store":["shopping"],
    "Casino":["hangout"],
    "Retail/Office/Carpark":["shopping"],
    "Indoor Recreation Facility":["sport"],
    "Cinema":["cinema"],
    "Library":["library"],
    "Private Sports Club/Facility":["sport"],
    "Observation Tower/Wheel":["hangout"],
    "Marina":["hangout"],
    "Church":["religious"],
    "Informal Outdoor Facility (Park/Garden/Reserve)":["hangout","sport","park"],
    "Art Gallery/Museum":["museum"],
    "Major Sports & Recreation Facility":["spectator of sport"],
    "Outdoor Recreation Facility (Zoo, Golf Course)":["hangout", "sport","park"],
    "Theatre Live":["cinema"],
    "Public Buildings":["hangout","park","spectator of sport"],
    "Aquarium":["hangout"],
    "Retail":["shopping"],
    "Gymnasium/Health Club":["sport"]
}

# %%
poi1_final['interest'] = [', '.join(poi_sub_theme_activity_dict[i]) for i in poi1_final['Sub Theme']]

# %%
poi1_final[['poi_id',
            'Feature Name',
            'Theme', 
            'Sub Theme', 
            'lat','lon',
            'interest']].to_csv('Dataset/Final/POI_FINAL.csv',index=False)

# %%
## UPDATED AS PREVIOUS CELL
# poi_ids = []
# poi_interests = []

# for idx in poi1_final.index:
#     interest_list = poi_sub_theme_activity_dict[poi1_final.loc[idx]['Sub Theme']]
#     for interest in interest_list:
#         poi_ids.append(poi1_final.loc[idx]['poi_id'])
#         poi_interests.append(interest_dict[interest])
        
# interest_poi_df = pd.DataFrame({
#                                 "poi_interest_id": [idx+1 for idx in range(len(poi_ids))],
#                                 "poi_id":poi_ids,
#                                 "interest_id": poi_interests
#                                })
# interest_poi_df
# Out:
#      poi_interest_id  poi_id  interest_id
# 0                  1       1            9
# 1                  2       2            1
# 2                  3       3            4
# 3                  4       3            3
# 4                  5       3            8
# ..               ...     ...          ...
# 252              253     155            4
# 253              254     155            3
# 254              255     155            8
# 255              256     156            7
# 256              257     157            9
#
# [257 rows x 3 columns]

# %%
interest_poi_df.to_csv('Dataset/Final/interest_poi.csv', index=False)

# Export interest list
interest_df = pd.DataFrame(interest_dict.items(),columns=['name','interest_id']) 
interest_df.to_csv('Dataset/Final/interest.csv', index=False)

# %% [markdown]
# ### Add Water Fountain Data
#
# Created : 22 April 2020

# %%
water_df
# Out:
#                                            Description  \
# 0    Drinking Fountain - Stainless Steel Drinking F...
# 1    Drinking Fountain - Stainless Steel Drinking F...
# 2    Drinking Fountain - Stainless Steel Drinking F...
# 3    Drinking Fountain - Stainless Steel Drinking F...
# 4    Drinking Fountain - Treated Timber Drinking Fo...
# ..                                                 ...
# 296  Drinking Fountain - Stainless Steel Drinking F...
# 297  Drinking Fountain - Leaf Type - With Bottle Re...
# 298  Drinking Fountain - Stainless Steel Drinking F...
# 299  Drinking fountain - Historic or Heritage Drink...
# 300  Drinking Fountain - Stainless Steel Drinking F...
#
#                                   Co-ordinates        lat         lon
# 0    (-37.815185695578855, 144.95257756009232) -37.815186  144.952578
# 1    (-37.824688315009205, 144.94695310036423) -37.824688  144.946953
# 2    (-37.819376190936254, 144.96425791163875) -37.819376  144.964258
# 3     (-37.81337112781817, 144.94357125504956) -37.813371  144.943571
# 4     (-37.79365820618429, 144.92352614663906) -37.793658  144.923526
# ..                                         ...        ...         ...
# 296   (-37.82317712092532, 144.94186784766944) -37.823177  144.941868
# 297    (-37.82168006484173, 144.9700370336942) -37.821680  144.970037
# 298    (-37.82605853691661, 144.9615312833258) -37.826059  144.961531
# 299  (-37.827087271632976, 144.98504460154422) -37.827087  144.985045
# 300     (-37.8212095645359, 144.9694728091101) -37.821210  144.969473
#
# [301 rows x 4 columns]

# %%
get_nearest_items(-37.815186,144.952578,'V',water_df,0)[['Description','lat','lon','distance']].to_csv('temp.csv')

# %%
water_final_df = []
for i in poi1_final.index:
    res_df = get_nearest_items(poi1_final.loc[i]['lat'],
                         poi1_final.loc[i]['lon'],
                         poi1_final.loc[i]['poi_id'],
                        water_df, 0)

    if i==0:
        water_final_df = res_df
    else:
        water_final_df = water_final_df.append(res_df)

# %%
water_final_df
# Out:
#     index                                        Description  \
# 0     232  Drinking Fountain - Stainless Steel Drinking F...
# 1      83  Drinking Fountain - Stainless Steel Drinking F...
# 2     259  Drinking Fountain - Stainless Steel Drinking F...
# 0     259  Drinking Fountain - Stainless Steel Drinking F...
# 1     232  Drinking Fountain - Stainless Steel Drinking F...
# ..    ...                                                ...
# 1      26  Drinking Fountain - Stainless Steel Drinking F...
# 2     110  Drinking Fountain - Stainless Steel Drinking F...
# 0     168     Drinking Fountain - Drinking Fountain - Type 1
# 1      18  Drinking Fountain - Stainless Steel Drinking F...
# 2      73  Drinking Fountain - Stainless Steel Drinking F...
#
#                                  Co-ordinates        lat         lon  \
# 0    (-37.81437201868546, 144.96613327636365) -37.814372  144.966133
# 1     (-37.81331469375451, 144.9666513135716) -37.813315  144.966651
# 2   (-37.815447719564624, 144.96705501075527) -37.815448  144.967055
# 0   (-37.815447719564624, 144.96705501075527) -37.815448  144.967055
# 1    (-37.81437201868546, 144.96613327636365) -37.814372  144.966133
# ..                                        ...        ...         ...
# 1    (-37.81191194838843, 144.97076931535327) -37.811912  144.970769
# 2     (-37.81261776692698, 144.9683505786709) -37.812618  144.968351
# 0    (-37.81522141134258, 144.96172628554172) -37.815221  144.961726
# 1   (-37.814969228345504, 144.96035042039261) -37.814969  144.960350
# 2     (-37.8175239427856, 144.96013037555608) -37.817524  144.960130
#
#      distance  poi_id
# 0    3.280500       1
# 1    6.024251       1
# 2    8.027003       1
# 0    3.885271       2
# 1    8.034562       2
# ..        ...     ...
# 1   12.160568     156
# 2   13.054973     156
# 0    5.983261     157
# 1   11.303314     157
# 2   13.093811     157
#
# [471 rows x 7 columns]

# %%
# Save the dataset
water_final_df['water_id'] = [i+1 for i in range(len(water_final_df))]
water_final_df = water_final_df[['water_id','poi_id','Description','lat','lon','distance']]
water_final_df.to_csv('Dataset/Final/Nearest_water_fountain.csv', index=False)
